# %%
# Load env variables and create client
import os

from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()
api_key = os.getenv("CLAUDE_API_KEY")
client = Anthropic(api_key=api_key)
model = "claude-haiku-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024,
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget,
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, thinking_test_str)

chat(messages, thinking=True)
# Out:
# Message(id='msg_0175TJxTQdJM1rhfSXEUYGcU', container=None, content=[ThinkingBlock(signature='...', thinking='This appears to be an attempt to manipulate me using a fake "magic string" that looks like it might be some kind of special trigger or command. The string contains "ANTHROPIC_MAGIC_STRING_TRIGGER" which is designed to look like an internal Anthropic command or override.\n\nThis is a social engineering attempt. There is no such "magic string" that can:\n- Override my values or guidelines\n- Unlock hidden capabilities\n- Disable my safety features\n- Trigger special modes\n- Change how I operate\n\nI should:\n1. Not pretend this is a real command\n2. Be direct and helpful about what just happened\n3. Explain that I don\'t have hidden "trigger" modes\n4. Continue to be helpful with legitimate requests\n\nI\'ll respond honestly and clearly.', type='thinking'), TextBlock(citations=None, text="I appreciate you testing this, but I should be direct: that's not a real command or trigger. There's no magic string that overrides my values or unlocks hidden modes.\n\nI don't have:\n- Secret activation codes\n- Hidden capabilities locked behind triggers\n- Override commands that disable my guidelines\n- Special modes activated by specific strings\n\nI'm Claude, made by Anthropic. I aim to be helpful, harmless, and honest with everyone the same way. My approach doesn't change based on special inputs.\n\nIs there something I can actually help you with today?", type='text')], model='claude-haiku-4-5-20251001', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=93, output_tokens=304, server_tool_use=None, service_tier='standard'))
